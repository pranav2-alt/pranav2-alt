# %%
import pandas as pd

# %% [markdown]
# # Working with json file

# %%
df = pd.read_json("C:\\Users\\saurabh\\Desktop\\Newdat\\recipe.json")

# %%
df.head(3)
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...

# %% [markdown]
# # working with API

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ...

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql.connector
# Out:
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\saurabh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\saurabh\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\saurabh\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host = 'localhost' ,
                               user = 'root' ,
                               password = '' ,
                               database = 'rajatdata')

# %%
pd.read_sql_query("SELECT * FROM  covid_toy" , conn)
# Out:
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_3224\2917151387.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM  covid_toy" , conn)
#     age  gender fever   cough       city has_covid
# 0    60    Male  103.    Mild    Kolkata        No
# 1    27    Male  100.    Mild      Delhi       Yes
# 2    42    Male  101.    Mild      Delhi        No
# 3    31  Female  98.0    Mild    Kolkata        No
# 4    65  Female  101.    Mild     Mumbai        No
# ..  ...     ...   ...     ...        ...       ...
# 95   12  Female  104.    Mild  Bangalore        No
# 96   51  Female  101.  Strong    Kolkata       Yes
# 97   20  Female  101.    Mild  Bangalore        No
# 98    5  Female  98.0  Strong     Mumbai        No
# 99   10  Female  98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
pd.read_sql_query("SELECT * FROM  covid_toy WHERE cough LIKE 'Mild'" , conn)
# Out:
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_3224\3016863056.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM  covid_toy WHERE cough LIKE 'Mild'" , conn)
#     age  gender fever cough       city has_covid
# 0    60    Male  103.  Mild    Kolkata        No
# 1    27    Male  100.  Mild      Delhi       Yes
# 2    42    Male  101.  Mild      Delhi        No
# 3    31  Female  98.0  Mild    Kolkata        No
# 4    65  Female  101.  Mild     Mumbai        No
# ..  ...     ...   ...   ...        ...       ...
# 57    5  Female  100.  Mild    Kolkata        No
# 58   38    Male        Mild      Delhi       Yes
# 59   27    Male  100.  Mild    Kolkata       Yes
# 60   12  Female  104.  Mild  Bangalore        No
# 61   20  Female  101.  Mild  Bangalore        No
#
# [62 rows x 6 columns]

# %%
pd.read_sql_query("SELECT * FROM  covid_toy WHERE has_covid LIKE 'Yes'" , conn)
# Out:
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_3224\2738141048.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM  covid_toy WHERE has_covid LIKE 'Yes'" , conn)
#     age  gender fever   cough       city has_covid
# 0    27    Male  100.    Mild      Delhi       Yes
# 1    84  Female          Mild  Bangalore       Yes
# 2    20  Female        Strong     Mumbai       Yes
# 3    65  Female  98.0    Mild     Mumbai       Yes
# 4    64    Male  102.    Mild  Bangalore       Yes
# 5    70    Male  103.  Strong    Kolkata       Yes
# 6    69  Female  103.    Mild    Kolkata       Yes
# 7    64  Female  98.0    Mild  Bangalore       Yes
# 8    42  Female        Strong  Bangalore       Yes
# 9    73    Male  98.0    Mild  Bangalore       Yes
# 10   71  Female  98.0  Strong    Kolkata       Yes
# ...

# %%
pd.read_sql_query("SELECT * FROM  covid_toy  WHERE age > 30 " , conn)
# Out:
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_3224\3221860719.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM  covid_toy  WHERE age > 30 " , conn)
#     age  gender fever   cough       city has_covid
# 0    60    Male  103.    Mild    Kolkata        No
# 1    42    Male  101.    Mild      Delhi        No
# 2    31  Female  98.0    Mild    Kolkata        No
# 3    65  Female  101.    Mild     Mumbai        No
# 4    84  Female          Mild  Bangalore       Yes
# ..  ...     ...   ...     ...        ...       ...
# 58   59  Female  99.0  Strong      Delhi        No
# 59   38    Male          Mild      Delhi       Yes
# 60   82  Female  102.  Strong    Kolkata        No
# 61   79    Male        Strong    Kolkata       Yes
# 62   51  Female  101.  Strong    Kolkata       Yes
#
# ...

# %%
df2 = pd.read_sql_query("SELECT * FROM  covid_toy  WHERE city = 'Delhi' " , conn)
# Out:
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_3224\1335220645.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2 = pd.read_sql_query("SELECT * FROM  covid_toy  WHERE city = 'Delhi' " , conn)

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = df2[['age' , 'cough' , 'has_covid']]

# %% [markdown]
# # example - 2

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host = 'localhost' ,
                               user = 'root' ,
                               password = '' ,
                               database = 'pranavdata')

# %%
pd.read_sql_query("SELECT * FROM  attrition" , conn)
# Out:
# C:\Users\saurabh\AppData\Local\Temp\ipykernel_3224\1143496664.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM  attrition" , conn)
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# ...
